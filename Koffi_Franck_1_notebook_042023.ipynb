# %% [markdown]
# # 1 Imports & install

# %%
#!pip install seaborn

# %%
import pandas as pd
import numpy as np

# %%
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
import missingno as msno

# %%
DISPLAY = False

# %% [markdown]
# # 2 Chargement des Fichiers

# %% [markdown]
# ## 2.1 Country

# %%
# importer le fichier csv sur le notebook
country = pd.read_csv('Dataset_Edstat/EdStatsCountry.csv')

# %%
# visualiser le nombre de lignes et de colonnes du fichier csv
country.shape
# Out:
# (241, 32)

# %%
country.head(3)
# Out:
#   Country Code   Short Name   Table Name                     Long Name  \
# 0          ABW        Aruba        Aruba                         Aruba
# 1          AFG  Afghanistan  Afghanistan  Islamic State of Afghanistan
# 2          AGO       Angola       Angola   People's Republic of Angola
#
#   2-alpha code   Currency Unit  \
# 0           AW   Aruban florin
# 1           AF  Afghan afghani
# 2           AO  Angolan kwanza
#
#                                                                                                                                                                                                                                        Special Notes  \
# 0                                                                                                      SNA data for 2000-2011 are updated from official government statistics; 1994-1999 from UN databases. Base year has changed from 1995 to 2000.
# ...

# %% [markdown]
# ## 2.2 Data

# %%
data= pd.read_csv('Dataset_Edstat/EdStatsData.csv')
data.head(3)
# Out:
#   Country Name Country Code  \
# 0   Arab World          ARB
# 1   Arab World          ARB
# 2   Arab World          ARB
#
#                                                             Indicator Name  \
# 0             Adjusted net enrolment rate, lower secondary, both sexes (%)
# 1                 Adjusted net enrolment rate, lower secondary, female (%)
# 2  Adjusted net enrolment rate, lower secondary, gender parity index (GPI)
#
#    Indicator Code  1970  1971  1972  1973  1974  1975  ...  2060  2065  2070  \
# 0      UIS.NERA.2   NaN   NaN   NaN   NaN   NaN   NaN  ...   NaN   NaN   NaN
# 1    UIS.NERA.2.F   NaN   NaN   NaN   NaN   NaN   NaN  ...   NaN   NaN   NaN
# 2  UIS.NERA.2.GPI   NaN   NaN   NaN   NaN   NaN   NaN  ...   NaN   NaN   NaN
#
#    2075  2080  2085  2090  2095  2100  Unnamed: 69
# 0   NaN   NaN   NaN   NaN   NaN   NaN          NaN
# 1   NaN   NaN   NaN   NaN   NaN   NaN          NaN
# 2   NaN   NaN   NaN   NaN   NaN   NaN          NaN
#
# [3 rows x 70 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 886930 entries, 0 to 886929
# Data columns (total 70 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   Country Name    886930 non-null  object
#  1   Country Code    886930 non-null  object
#  2   Indicator Name  886930 non-null  object
#  3   Indicator Code  886930 non-null  object
#  4   1970            72288 non-null   float64
#  5   1971            35537 non-null   float64
#  6   1972            35619 non-null   float64
#  7   1973            35545 non-null   float64
#  8   1974            35730 non-null   float64
#  9   1975            87306 non-null   float64
#  10  1976            37483 non-null   float64
#  11  1977            37574 non-null   float64
#  12  1978            37576 non-null   float64
#  13  1979            36809 non-null   float64
#  14  1980            89122 non-null   float64
#  15  1981            38777 non-null   float64
# ...

# %% [markdown]
# # 3 Options

# %%
#visualiser l'ensemble du dataframe, toutes les lignes et colonnes.Faire apparaitre l'ensemble des informations.
pd.set_option("display.max_rows", 20) # EVITER DE METTRE 200
pd.set_option("display.max_column", 20) # EVITER DE METTRE 70
pd.set_option("display.max_colwidth", None)

#l'ensemble du dataframe, 241 lignes et 32 colonnes
country.head(2)
# Out:
#   Country Code   Short Name   Table Name                     Long Name  \
# 0          ABW        Aruba        Aruba                         Aruba
# 1          AFG  Afghanistan  Afghanistan  Islamic State of Afghanistan
#
#   2-alpha code   Currency Unit  \
# 0           AW   Aruban florin
# 1           AF  Afghan afghani
#
#                                                                                                                                                                                                                                        Special Notes  \
# 0                                                                                                      SNA data for 2000-2011 are updated from official government statistics; 1994-1999 from UN databases. Base year has changed from 1995 to 2000.
# ...

# %% [markdown]
# # 4 First Tour

# %% [markdown]
# ## 4.1 Country

# %%
country.columns[1]
# Out:
# 'Short Name'

# %%
country.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 241 entries, 0 to 240
# Data columns (total 32 columns):
#  #   Column                                             Non-Null Count  Dtype
# ---  ------                                             --------------  -----
#  0   Country Code                                       241 non-null    object
#  1   Short Name                                         241 non-null    object
#  2   Table Name                                         241 non-null    object
#  3   Long Name                                          241 non-null    object
#  4   2-alpha code                                       238 non-null    object
#  5   Currency Unit                                      215 non-null    object
#  6   Special Notes                                      145 non-null    object
#  7   Region                                             214 non-null    object
#  8   Income Group                                       214 non-null    object
# ...

# %%
country
# Out:
#     Country Code    Short Name    Table Name                     Long Name  \
# 0            ABW         Aruba         Aruba                         Aruba
# 1            AFG   Afghanistan   Afghanistan  Islamic State of Afghanistan
# 2            AGO        Angola        Angola   People's Republic of Angola
# 3            ALB       Albania       Albania           Republic of Albania
# 4            AND       Andorra       Andorra       Principality of Andorra
# ..           ...           ...           ...                           ...
# 236          XKX        Kosovo        Kosovo            Republic of Kosovo
# 237          YEM         Yemen   Yemen, Rep.             Republic of Yemen
# 238          ZAF  South Africa  South Africa      Republic of South Africa
# 239          ZMB        Zambia        Zambia            Republic of Zambia
# 240          ZWE      Zimbabwe      Zimbabwe          Republic of Zimbabwe
#
#     2-alpha code       Currency Unit  \
# ...

# %%
country
# Out:
#     Country Code    Short Name    Table Name                     Long Name  \
# 0            ABW         Aruba         Aruba                         Aruba
# 1            AFG   Afghanistan   Afghanistan  Islamic State of Afghanistan
# 2            AGO        Angola        Angola   People's Republic of Angola
# 3            ALB       Albania       Albania           Republic of Albania
# 4            AND       Andorra       Andorra       Principality of Andorra
# ..           ...           ...           ...                           ...
# 236          XKX        Kosovo        Kosovo            Republic of Kosovo
# 237          YEM         Yemen   Yemen, Rep.             Republic of Yemen
# 238          ZAF  South Africa  South Africa      Republic of South Africa
# 239          ZMB        Zambia        Zambia            Republic of Zambia
# 240          ZWE      Zimbabwe      Zimbabwe          Republic of Zimbabwe
#
#     2-alpha code       Currency Unit  \
# ...

# %%
country.loc[country["Currency Unit"].isna()]
# Out:
#     Country Code                                 Short Name  \
# 5            ARB                                 Arab World
# 57           EAP      East Asia & Pacific (developing only)
# 58           EAS    East Asia & Pacific (all income levels)
# 59           ECA    Europe & Central Asia (developing only)
# 60           ECS  Europe & Central Asia (all income levels)
# ..           ...                                        ...
# 187          SAS                                 South Asia
# 198          SSA       Sub-Saharan Africa (developing only)
# 200          SSF     Sub-Saharan Africa (all income levels)
# 225          UMC                        Upper middle income
# 234          WLD                                      World
#
#                                     Table Name  \
# 5                                   Arab World
# 57                         East Asia & Pacific
# 58     East Asia & Pacific (all income levels)
# 59                       Europe & Central Asia
# ...

# %%
regions_not_countries_list = country.loc[country["Currency Unit"].isna(), "Short Name"].values
regions_not_countries_list
# Out:
# array(['Arab World', 'East Asia & Pacific (developing only)',
#        'East Asia & Pacific (all income levels)',
#        'Europe & Central Asia (developing only)',
#        'Europe & Central Asia (all income levels)', 'Euro area',
#        'European Union', 'High income',
#        'Heavily indebted poor countries (HIPC)',
#        'Latin America & Caribbean (developing only)',
#        'Latin America & Caribbean (all income levels)',
#        'Least developed countries: UN classification', 'Low income',
#        'Lower middle income', 'Low & middle income',
#        'Middle East & North Africa (all income levels)', 'Middle income',
#        'Middle East & North Africa (developing only)', 'North America',
#        'Nauru', 'OECD members', 'South Asia',
#        'Sub-Saharan Africa (developing only)',
#        'Sub-Saharan Africa (all income levels)', 'Upper middle income',
#        'World'], dtype=object)

# %%
country['National accounts reference year']
# Out:
# 0         NaN
# 1         NaN
# 2         NaN
# 3      1996.0
# 4         NaN
#         ...
# 236       NaN
# 237       NaN
# 238       NaN
# 239       NaN
# 240       NaN
# Name: National accounts reference year, Length: 241, dtype: float64

# %%
country.columns
# Out:
# Index(['Country Code', 'Short Name', 'Table Name', 'Long Name', '2-alpha code',
#        'Currency Unit', 'Special Notes', 'Region', 'Income Group', 'WB-2 code',
#        'National accounts base year', 'National accounts reference year',
#        'SNA price valuation', 'Lending category', 'Other groups',
#        'System of National Accounts', 'Alternative conversion factor',
#        'PPP survey year', 'Balance of Payments Manual in use',
#        'External debt Reporting status', 'System of trade',
#        'Government Accounting concept', 'IMF data dissemination standard',
#        'Latest population census', 'Latest household survey',
#        'Source of most recent Income and expenditure data',
#        'Vital registration complete', 'Latest agricultural census',
#        'Latest industrial data', 'Latest trade data',
#        'Latest water withdrawal data', 'Unnamed: 31'],
#       dtype='object')

# %%
country=country.drop(labels='Latest trade data',axis=1)
country.columns
# Out:
# Index(['Country Code', 'Short Name', 'Table Name', 'Long Name', '2-alpha code',
#        'Currency Unit', 'Special Notes', 'Region', 'Income Group', 'WB-2 code',
#        'National accounts base year', 'National accounts reference year',
#        'SNA price valuation', 'Lending category', 'Other groups',
#        'System of National Accounts', 'Alternative conversion factor',
#        'PPP survey year', 'Balance of Payments Manual in use',
#        'External debt Reporting status', 'System of trade',
#        'Government Accounting concept', 'IMF data dissemination standard',
#        'Latest population census', 'Latest household survey',
#        'Source of most recent Income and expenditure data',
#        'Vital registration complete', 'Latest agricultural census',
#        'Latest industrial data', 'Latest water withdrawal data',
#        'Unnamed: 31'],
#       dtype='object')

# %%
#country=country.drop(columns=['Table Name', 'Long Name'])
country.columns
# Out:
# Index(['Country Code', 'Short Name', 'Table Name', 'Long Name', '2-alpha code',
#        'Currency Unit', 'Special Notes', 'Region', 'Income Group', 'WB-2 code',
#        'National accounts base year', 'National accounts reference year',
#        'SNA price valuation', 'Lending category', 'Other groups',
#        'System of National Accounts', 'Alternative conversion factor',
#        'PPP survey year', 'Balance of Payments Manual in use',
#        'External debt Reporting status', 'System of trade',
#        'Government Accounting concept', 'IMF data dissemination standard',
#        'Latest population census', 'Latest household survey',
#        'Source of most recent Income and expenditure data',
#        'Vital registration complete', 'Latest agricultural census',
#        'Latest industrial data', 'Latest water withdrawal data',
#        'Unnamed: 31'],
#       dtype='object')

# %%
country=country[['Country Code','Short Name','Region', 'Income Group']]
country.columns
# Out:
# Index(['Country Code', 'Short Name', 'Region', 'Income Group'], dtype='object')

# %%
country.head()
# Out:
#   Country Code   Short Name                     Region          Income Group
# 0          ABW        Aruba  Latin America & Caribbean  High income: nonOECD
# 1          AFG  Afghanistan                 South Asia            Low income
# 2          AGO       Angola         Sub-Saharan Africa   Upper middle income
# 3          ALB      Albania      Europe & Central Asia   Upper middle income
# 4          AND      Andorra      Europe & Central Asia  High income: nonOECD

# %%
#renommer une colonne
country=country.rename(columns={'Short Name': 'Country Name'})
country.columns
# Out:
# Index(['Country Code', 'Country Name', 'Region', 'Income Group'], dtype='object')

# %%
#chercher les NaN country.isna()
country.isna().sum()
# Out:
# Country Code     0
# Country Name     0
# Region          27
# Income Group    27
# dtype: int64

# %%
#accéder a un pays spécifique
country[country['Country Name']=='France']
# Out:
#    Country Code Country Name                 Region       Income Group
# 71          FRA       France  Europe & Central Asia  High income: OECD

# %%
#trouver les colonnes NaN
region_Nan=country[country['Region'].isna()]
region_Nan
# Out:
#     Country Code                               Country Name Region  \
# 5            ARB                                 Arab World    NaN
# 57           EAP      East Asia & Pacific (developing only)    NaN
# 58           EAS    East Asia & Pacific (all income levels)    NaN
# 59           ECA    Europe & Central Asia (developing only)    NaN
# 60           ECS  Europe & Central Asia (all income levels)    NaN
# ..           ...                                        ...    ...
# 187          SAS                                 South Asia    NaN
# 198          SSA       Sub-Saharan Africa (developing only)    NaN
# 200          SSF     Sub-Saharan Africa (all income levels)    NaN
# 225          UMC                        Upper middle income    NaN
# 234          WLD                                      World    NaN
#
#     Income Group
# 5            NaN
# 57           NaN
# 58           NaN
# 59           NaN
# 60           NaN
# ..           ...
# 187          NaN
# ...

# %%
country[country['Region']=='Europe & Central Asia']
# Out:
#     Country Code  Country Name                 Region          Income Group
# 3            ALB       Albania  Europe & Central Asia   Upper middle income
# 4            AND       Andorra  Europe & Central Asia  High income: nonOECD
# 8            ARM       Armenia  Europe & Central Asia   Lower middle income
# 12           AUT       Austria  Europe & Central Asia     High income: OECD
# 13           AZE    Azerbaijan  Europe & Central Asia   Upper middle income
# ..           ...           ...                    ...                   ...
# 215          TKM  Turkmenistan  Europe & Central Asia   Upper middle income
# 220          TUR        Turkey  Europe & Central Asia   Upper middle income
# 224          UKR       Ukraine  Europe & Central Asia   Lower middle income
# 228          UZB    Uzbekistan  Europe & Central Asia   Lower middle income
# 236          XKX        Kosovo  Europe & Central Asia   Lower middle income
#
# [57 rows x 4 columns]

# %%
#pour éliminer les régions qui ne sont pas des pays et qui contiennent des NaN axis=0 ligne/axis=1 colonne/thresh =valeur Supression NaN
#country.dropna(axis=0,thresh=4)
#country.drop(columns='Region')
country=country[country['Region'].notna()].reset_index(drop=True)
country
# Out:
#     Country Code  Country Name                      Region  \
# 0            ABW         Aruba   Latin America & Caribbean
# 1            AFG   Afghanistan                  South Asia
# 2            AGO        Angola          Sub-Saharan Africa
# 3            ALB       Albania       Europe & Central Asia
# 4            AND       Andorra       Europe & Central Asia
# ..           ...           ...                         ...
# 209          XKX        Kosovo       Europe & Central Asia
# 210          YEM         Yemen  Middle East & North Africa
# 211          ZAF  South Africa          Sub-Saharan Africa
# 212          ZMB        Zambia          Sub-Saharan Africa
# 213          ZWE      Zimbabwe          Sub-Saharan Africa
#
#              Income Group
# 0    High income: nonOECD
# 1              Low income
# 2     Upper middle income
# 3     Upper middle income
# 4    High income: nonOECD
# ..                    ...
# 209   Lower middle income
# 210   Lower middle income
# ...

# %% [markdown]
# ## 4.2 Data

# %%
#visualisation
print(data['Indicator Name'].unique())
pd.unique(data['Indicator Name'])
_ = [print(elem) for elem in data['Indicator Name'].unique()]
# Out:
# ['Adjusted net enrolment rate, lower secondary, both sexes (%)'
#  'Adjusted net enrolment rate, lower secondary, female (%)'
#  'Adjusted net enrolment rate, lower secondary, gender parity index (GPI)'
#  ... 'Youth literacy rate, population 15-24 years, female (%)'
#  'Youth literacy rate, population 15-24 years, gender parity index (GPI)'
#  'Youth literacy rate, population 15-24 years, male (%)']
# Adjusted net enrolment rate, lower secondary, both sexes (%)
# Adjusted net enrolment rate, lower secondary, female (%)
# Adjusted net enrolment rate, lower secondary, gender parity index (GPI)
# Adjusted net enrolment rate, lower secondary, male (%)
# Adjusted net enrolment rate, primary, both sexes (%)
# Adjusted net enrolment rate, primary, female (%)
# Adjusted net enrolment rate, primary, gender parity index (GPI)
# Adjusted net enrolment rate, primary, male (%)
# Adjusted net enrolment rate, upper secondary, both sexes (%)
# ...

# %%
data[data.duplicated(subset='Indicator Name')]['Indicator Name']
# Out:
# 3665                 Adjusted net enrolment rate, lower secondary, both sexes (%)
# 3666                     Adjusted net enrolment rate, lower secondary, female (%)
# 3667      Adjusted net enrolment rate, lower secondary, gender parity index (GPI)
# 3668                       Adjusted net enrolment rate, lower secondary, male (%)
# 3669                         Adjusted net enrolment rate, primary, both sexes (%)
#                                            ...
# 886925                    Youth illiterate population, 15-24 years, male (number)
# 886926                Youth literacy rate, population 15-24 years, both sexes (%)
# 886927                    Youth literacy rate, population 15-24 years, female (%)
# 886928     Youth literacy rate, population 15-24 years, gender parity index (GPI)
# 886929                      Youth literacy rate, population 15-24 years, male (%)
# Name: Indicator Name, Length: 883265, dtype: object

# %%
data[data.duplicated(subset='Indicator Name')]['Indicator Name']
# Out:
# 3665                 Adjusted net enrolment rate, lower secondary, both sexes (%)
# 3666                     Adjusted net enrolment rate, lower secondary, female (%)
# 3667      Adjusted net enrolment rate, lower secondary, gender parity index (GPI)
# 3668                       Adjusted net enrolment rate, lower secondary, male (%)
# 3669                         Adjusted net enrolment rate, primary, both sexes (%)
#                                            ...
# 886925                    Youth illiterate population, 15-24 years, male (number)
# 886926                Youth literacy rate, population 15-24 years, both sexes (%)
# 886927                    Youth literacy rate, population 15-24 years, female (%)
# 886928     Youth literacy rate, population 15-24 years, gender parity index (GPI)
# 886929                      Youth literacy rate, population 15-24 years, male (%)
# Name: Indicator Name, Length: 883265, dtype: object

# %%
print(data['Indicator Name'].values) 
#print(data['Country Name'].values)
# Out:
# ['Adjusted net enrolment rate, lower secondary, both sexes (%)'
#  'Adjusted net enrolment rate, lower secondary, female (%)'
#  'Adjusted net enrolment rate, lower secondary, gender parity index (GPI)'
#  ... 'Youth literacy rate, population 15-24 years, female (%)'
#  'Youth literacy rate, population 15-24 years, gender parity index (GPI)'
#  'Youth literacy rate, population 15-24 years, male (%)']

# %%
#pour éliminer les régions qui ne sont pas des pays et qui contiennent des NaN axis=0 ligne/axis=1 colonne/thresh =valeur Supression NaN
#country.dropna(axis=0,thresh=4)
#country.drop(columns='Region')
##country=country[country['Region'].notna()].reset_index(drop=True)
#country
data.columns
# Out:
# Index(['Country Name', 'Country Code', 'Indicator Name', 'Indicator Code',
#        '1970', '1971', '1972', '1973', '1974', '1975', '1976', '1977', '1978',
#        '1979', '1980', '1981', '1982', '1983', '1984', '1985', '1986', '1987',
#        '1988', '1989', '1990', '1991', '1992', '1993', '1994', '1995', '1996',
#        '1997', '1998', '1999', '2000', '2001', '2002', '2003', '2004', '2005',
#        '2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013', '2014',
#        '2015', '2016', '2017', '2020', '2025', '2030', '2035', '2040', '2045',
#        '2050', '2055', '2060', '2065', '2070', '2075', '2080', '2085', '2090',
#        '2095', '2100', 'Unnamed: 69'],
#       dtype='object')

# %%
#les informations du data frame
informartion=data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 886930 entries, 0 to 886929
# Data columns (total 70 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   Country Name    886930 non-null  object
#  1   Country Code    886930 non-null  object
#  2   Indicator Name  886930 non-null  object
#  3   Indicator Code  886930 non-null  object
#  4   1970            72288 non-null   float64
#  5   1971            35537 non-null   float64
#  6   1972            35619 non-null   float64
#  7   1973            35545 non-null   float64
#  8   1974            35730 non-null   float64
#  9   1975            87306 non-null   float64
#  10  1976            37483 non-null   float64
#  11  1977            37574 non-null   float64
#  12  1978            37576 non-null   float64
#  13  1979            36809 non-null   float64
#  14  1980            89122 non-null   float64
#  15  1981            38777 non-null   float64
# ...

# %%
#accéder à une ligne
#data.info()[5][2]

# %%
#nombre de lignes
nb_ligne=data.shape
nb_ligne
# Out:
# (886930, 70)

# %%
#chercher les NaN
nb_nan=data.isna().sum()
nb_nan
# Out:
# Country Name           0
# Country Code           0
# Indicator Name         0
# Indicator Code         0
# 1970              814642
#                    ...
# 2085              835494
# 2090              835494
# 2095              835494
# 2100              835494
# Unnamed: 69       886930
# Length: 70, dtype: int64

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 886930 entries, 0 to 886929
# Data columns (total 70 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   Country Name    886930 non-null  object
#  1   Country Code    886930 non-null  object
#  2   Indicator Name  886930 non-null  object
#  3   Indicator Code  886930 non-null  object
#  4   1970            72288 non-null   float64
#  5   1971            35537 non-null   float64
#  6   1972            35619 non-null   float64
#  7   1973            35545 non-null   float64
#  8   1974            35730 non-null   float64
#  9   1975            87306 non-null   float64
#  10  1976            37483 non-null   float64
#  11  1977            37574 non-null   float64
#  12  1978            37576 non-null   float64
#  13  1979            36809 non-null   float64
#  14  1980            89122 non-null   float64
#  15  1981            38777 non-null   float64
# ...

# %%
#data.shape
#taux_remplissage=data[(data.info())//(data.shape())/100]

# %%
# boucle sur les colonnes 
print(data.shape)
nb_ligne = data.shape[0]
#tableau_taux=[]
for col in data.columns :
    print(col)
    #print(data[col].isna().sum())
    #print(data[col].notna().sum())
    #calcul du taux de remplissage (sans les NaN)
    taux_remp = data[col].notna().sum()/nb_ligne*100
    print(taux_remp,'%')
    #Mettre dans un tableau 
    #tableau_taux = [tableau_taux + [col, taux_remp]]
#tableau_taux
# Out:
# (886930, 70)
# Country Name
# 100.0 %
# Country Code
# 100.0 %
# Indicator Name
# 100.0 %
# Indicator Code
# 100.0 %
# 1970
# 8.150361358844552 %
# 1971
# 4.006742358472484 %
# 1972
# 4.015987732966525 %
# 1973
# 4.007644346228 %
# 1974
# 4.028502813074312 %
# 1975
# 9.843617872887375 %
# 1976
# 4.226150880001804 %
# 1977
# 4.236410990720801 %
# 1978
# 4.23663648765968 %
# 1979
# 4.150158411599563 %
# 1980
# 10.048369093389557 %
# 1981
# 4.3720473994565525 %
# 1982
# 4.229307837146111 %
# 1983
# 4.336306134644222 %
# 1984
# 4.352767411182393 %
# 1985
# 10.180735796511563 %
# 1986
# 4.439132738773071 %
# 1987
# 4.356713607612776 %
# 1988
# 4.346678993832659 %
# 1989
# 4.232577542759857 %
# 1990
# 14.0264733406244 %
# 1991
# 8.392657819670097 %
# 1992
# 8.517357626870217 %
# 1993
# 8.545544744230098 %
# 1994
# 8.733721939724669 %
# 1995
# 14.810751694045754 %
# 1996
# 8.659871692241778 %
# 1997
# 8.281713325741604 %
# 1998
# 9.573923533988026 %
# 1999
# 13.398915359723992 %
# 2000
# ...

# %%
if DISPLAY : 
    msno.matrix(data)

# %% [markdown]
# # 5 Cleaning

# %% [markdown]
# ## 5.1 Drop useless years

# %%
indicateurs=['Country Name','Country Code','Indicator Name','Indicator Code','2010','2011','2012','2013','2014','2015','2016',]
indicateurs
# Out:
# ['Country Name',
#  'Country Code',
#  'Indicator Name',
#  'Indicator Code',
#  '2010',
#  '2011',
#  '2012',
#  '2013',
#  '2014',
#  '2015',
#  '2016']

# %%
data=data.loc[:,indicateurs]
data.head()
# Out:
#   Country Name Country Code  \
# 0   Arab World          ARB
# 1   Arab World          ARB
# 2   Arab World          ARB
# 3   Arab World          ARB
# 4   Arab World          ARB
#
#                                                             Indicator Name  \
# 0             Adjusted net enrolment rate, lower secondary, both sexes (%)
# 1                 Adjusted net enrolment rate, lower secondary, female (%)
# 2  Adjusted net enrolment rate, lower secondary, gender parity index (GPI)
# 3                   Adjusted net enrolment rate, lower secondary, male (%)
# 4                     Adjusted net enrolment rate, primary, both sexes (%)
#
#    Indicator Code       2010      2011       2012      2013       2014  2015  \
# 0      UIS.NERA.2        NaN       NaN        NaN       NaN        NaN   NaN
# 1    UIS.NERA.2.F        NaN       NaN        NaN       NaN        NaN   NaN
# 2  UIS.NERA.2.GPI        NaN       NaN        NaN       NaN        NaN   NaN
# ...

# %%
msno.matrix(data)
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## 5.2 Drop regions

# %%
data["Country Name"].unique()
# Out:
# array(['Arab World', 'East Asia & Pacific',
#        'East Asia & Pacific (excluding high income)', 'Euro area',
#        'Europe & Central Asia',
#        'Europe & Central Asia (excluding high income)', 'European Union',
#        'Heavily indebted poor countries (HIPC)', 'High income',
#        'Latin America & Caribbean',
#        'Latin America & Caribbean (excluding high income)',
#        'Least developed countries: UN classification',
#        'Low & middle income', 'Low income', 'Lower middle income',
#        'Middle East & North Africa',
#        'Middle East & North Africa (excluding high income)',
#        'Middle income', 'North America', 'OECD members', 'South Asia',
#        'Sub-Saharan Africa', 'Sub-Saharan Africa (excluding high income)',
#        'Upper middle income', 'World', 'Afghanistan', 'Albania',
#        'Algeria', 'American Samoa', 'Andorra', 'Angola',
#        'Antigua and Barbuda', 'Argentina', 'Armenia', 'Aruba',
# ...

# %%
len(data["Country Name"].unique())
# Out:
# 242

# %%
regions_not_countries_list
# Out:
# array(['Arab World', 'East Asia & Pacific (developing only)',
#        'East Asia & Pacific (all income levels)',
#        'Europe & Central Asia (developing only)',
#        'Europe & Central Asia (all income levels)', 'Euro area',
#        'European Union', 'High income',
#        'Heavily indebted poor countries (HIPC)',
#        'Latin America & Caribbean (developing only)',
#        'Latin America & Caribbean (all income levels)',
#        'Least developed countries: UN classification', 'Low income',
#        'Lower middle income', 'Low & middle income',
#        'Middle East & North Africa (all income levels)', 'Middle income',
#        'Middle East & North Africa (developing only)', 'North America',
#        'Nauru', 'OECD members', 'South Asia',
#        'Sub-Saharan Africa (developing only)',
#        'Sub-Saharan Africa (all income levels)', 'Upper middle income',
#        'World'], dtype=object)

# %%
data = data.loc[ ~ data["Country Name"].isin(regions_not_countries_list)]
data
# Out:
#                Country Name Country Code  \
# 3665    East Asia & Pacific          EAS
# 3666    East Asia & Pacific          EAS
# 3667    East Asia & Pacific          EAS
# 3668    East Asia & Pacific          EAS
# 3669    East Asia & Pacific          EAS
# ...                     ...          ...
# 886925             Zimbabwe          ZWE
# 886926             Zimbabwe          ZWE
# 886927             Zimbabwe          ZWE
# 886928             Zimbabwe          ZWE
# 886929             Zimbabwe          ZWE
#
#                                                                  Indicator Name  \
# 3665               Adjusted net enrolment rate, lower secondary, both sexes (%)
# 3666                   Adjusted net enrolment rate, lower secondary, female (%)
# 3667    Adjusted net enrolment rate, lower secondary, gender parity index (GPI)
# 3668                     Adjusted net enrolment rate, lower secondary, male (%)
# ...

# %%
data["Country Name"].unique()
# Out:
# array(['East Asia & Pacific',
#        'East Asia & Pacific (excluding high income)',
#        'Europe & Central Asia',
#        'Europe & Central Asia (excluding high income)',
#        'Latin America & Caribbean',
#        'Latin America & Caribbean (excluding high income)',
#        'Middle East & North Africa',
#        'Middle East & North Africa (excluding high income)',
#        'Sub-Saharan Africa', 'Sub-Saharan Africa (excluding high income)',
#        'Afghanistan', 'Albania', 'Algeria', 'American Samoa', 'Andorra',
#        'Angola', 'Antigua and Barbuda', 'Argentina', 'Armenia', 'Aruba',
#        'Australia', 'Austria', 'Azerbaijan', 'Bahamas, The', 'Bahrain',
#        'Bangladesh', 'Barbados', 'Belarus', 'Belgium', 'Belize', 'Benin',
#        'Bermuda', 'Bhutan', 'Bolivia', 'Bosnia and Herzegovina',
#        'Botswana', 'Brazil', 'British Virgin Islands',
#        'Brunei Darussalam', 'Bulgaria', 'Burkina Faso', 'Burundi',
# ...

# %%
len(data["Country Name"].unique())
# Out:
# 226

# %%
new_country_list_to_clean = ['East Asia & Pacific',
       'East Asia & Pacific (excluding high income)',
       'Europe & Central Asia',
       'Europe & Central Asia (excluding high income)',
       'Latin America & Caribbean',
       'Latin America & Caribbean (excluding high income)',
       'Middle East & North Africa',
       'Middle East & North Africa (excluding high income)',
       'Sub-Saharan Africa', 'Sub-Saharan Africa (excluding high income)']

# %%
data = data.loc[ ~ data["Country Name"].isin(new_country_list_to_clean)]
data
# Out:
#        Country Name Country Code  \
# 91625   Afghanistan          AFG
# 91626   Afghanistan          AFG
# 91627   Afghanistan          AFG
# 91628   Afghanistan          AFG
# 91629   Afghanistan          AFG
# ...             ...          ...
# 886925     Zimbabwe          ZWE
# 886926     Zimbabwe          ZWE
# 886927     Zimbabwe          ZWE
# 886928     Zimbabwe          ZWE
# 886929     Zimbabwe          ZWE
#
#                                                                  Indicator Name  \
# 91625              Adjusted net enrolment rate, lower secondary, both sexes (%)
# 91626                  Adjusted net enrolment rate, lower secondary, female (%)
# 91627   Adjusted net enrolment rate, lower secondary, gender parity index (GPI)
# 91628                    Adjusted net enrolment rate, lower secondary, male (%)
# 91629                      Adjusted net enrolment rate, primary, both sexes (%)
# ...

# %%
data["Country Name"].unique()
# Out:
# array(['Afghanistan', 'Albania', 'Algeria', 'American Samoa', 'Andorra',
#        'Angola', 'Antigua and Barbuda', 'Argentina', 'Armenia', 'Aruba',
#        'Australia', 'Austria', 'Azerbaijan', 'Bahamas, The', 'Bahrain',
#        'Bangladesh', 'Barbados', 'Belarus', 'Belgium', 'Belize', 'Benin',
#        'Bermuda', 'Bhutan', 'Bolivia', 'Bosnia and Herzegovina',
#        'Botswana', 'Brazil', 'British Virgin Islands',
#        'Brunei Darussalam', 'Bulgaria', 'Burkina Faso', 'Burundi',
#        'Cabo Verde', 'Cambodia', 'Cameroon', 'Canada', 'Cayman Islands',
#        'Central African Republic', 'Chad', 'Channel Islands', 'Chile',
#        'China', 'Colombia', 'Comoros', 'Congo, Dem. Rep.', 'Congo, Rep.',
#        'Costa Rica', "Cote d'Ivoire", 'Croatia', 'Cuba', 'Curacao',
#        'Cyprus', 'Czech Republic', 'Denmark', 'Djibouti', 'Dominica',
#        'Dominican Republic', 'Ecuador', 'Egypt, Arab Rep.', 'El Salvador',
#        'Equatorial Guinea', 'Eritrea', 'Estonia', 'Ethiopia',
# ...

# %%
len(data["Country Name"].unique())
# Out:
# 216

# %% [markdown]
# ## 5.3 Selection d'indicateurs

# %%
indicator_list = data["Indicator Name"].unique()
indicator_list
# Out:
# array(['Adjusted net enrolment rate, lower secondary, both sexes (%)',
#        'Adjusted net enrolment rate, lower secondary, female (%)',
#        'Adjusted net enrolment rate, lower secondary, gender parity index (GPI)',
#        ..., 'Youth literacy rate, population 15-24 years, female (%)',
#        'Youth literacy rate, population 15-24 years, gender parity index (GPI)',
#        'Youth literacy rate, population 15-24 years, male (%)'],
#       dtype=object)

# %%
print([i for i in indicator_list if "tertiary" in i.lower()])
# Out:
# ['All staff compensation as % of total expenditure in post-secondary non-tertiary public institutions (%)', 'All staff compensation as % of total expenditure in tertiary public institutions (%)', 'Barro-Lee: Average years of tertiary schooling, age 15+, female', 'Barro-Lee: Average years of tertiary schooling, age 15+, total', 'Barro-Lee: Average years of tertiary schooling, age 15-19, female', 'Barro-Lee: Average years of tertiary schooling, age 15-19, total', 'Barro-Lee: Average years of tertiary schooling, age 20-24, female', 'Barro-Lee: Average years of tertiary schooling, age 20-24, total', 'Barro-Lee: Average years of tertiary schooling, age 25+, female', 'Barro-Lee: Average years of tertiary schooling, age 25+, total', 'Barro-Lee: Average years of tertiary schooling, age 25-29, female', 'Barro-Lee: Average years of tertiary schooling, age 25-29, total', 'Barro-Lee: Average years of tertiary schooling, age 30-34, female', 'Barro-Lee: Average years of tertiary schooling, age 30-
# ...

# %%
# Sélection de colonnes à garder
 #data for (taux_remp_choisi = (data[col].notna().sum()/nb_ligne*100)>=25%):
           #print(taux_remp_choisi)

# %%
#for line in data : 
 #   print (line)

# %%
#Adjusted net enrolment rate, upper secondary, both sexes (%),#Adult literacy rate, population 15+ years, both sexes (%),
#Barro-Lee: Average years of secondary schooling, age 15+, total,#Barro-Lee: Average years of tertiary schooling, age 15+, total,
#Barro-Lee: Percentage of population age 15+ with secondary schooling. Completed Secondary,#Barro-Lee: Percentage of population age 15+ with tertiary schooling. Completed Tertiary,
#DHS: Secondary completion rate,
#GDP per capita (current US$),
#Graduates from tertiary education, both sexes (number)
#Gross enrolment ratio, secondary, both sexes (%),#Gross enrolment ratio, tertiary, both sexes (%),#Internet users (per 100 people)
#Labor force, total,#Literacy rate, population 25-64 years, both sexes (%),
#MICS: Net attendance rate. Secondary
#MICS: Secondary completion rate,#Personal computers (per 100 people),#Population growth (annual %),#Population, total,#School life expectancy, post-secondary non-tertiary, both sexes (years),#School life expectancy, tertiary, both sexes (years)
#Youth literacy rate, population 15-24 years, both sexes (%),/
# "Personal computers (per 100 people)",
#indicateur et Marché cible
##DHS: Secondary completion rate
##Enrolment in upper secondary education, both sexes (number)
##Enrolment in tertiary education, all programmes, both sexes (number)

# %%
#indicateur et Marché cible
#DHS: Secondary completion rate
#Enrolment in upper secondary education, both sexes (number)
#Enrolment in tertiary education, all programmes, both sexes (number)

indicator_name=["Adjusted net enrolment rate, upper secondary, both sexes (%)","Adult literacy rate, population 15+ years, both sexes (%)",
                "Barro-Lee: Average years of secondary schooling, age 15+, total","Barro-Lee: Average years of tertiary schooling, age 15+, total",
               "Barro-Lee: Percentage of population age 15+ with secondary schooling. Completed Secondary",
                "Barro-Lee: Percentage of population age 15+ with tertiary schooling. Completed Tertiary",
               "Graduates from tertiary education, both sexes (number)",
               "Gross enrolment ratio, secondary, both sexes (%)",
                "Gross enrolment ratio, tertiary, both sexes (%)",
               "Internet users (per 100 people)","Labor force, total","Literacy rate, population 25-64 years, both sexes (%)",
               "MICS: Net attendance rate. Secondary","MICS: Secondary completion rate",
               "Population growth (annual %)",
                "Population, total","School life expectancy, post-secondary non-tertiary, both sexes (years)","School life expectancy, tertiary, both sexes (years)",
                "Youth literacy rate, population 15-24 years, both sexes (%)",
                "DHS: Secondary completion rate",
                "GDP per capita (current US$)",
                "Enrolment in tertiary education, all programmes, both sexes (number)",
               'Unemployment, total (% of total labor force)']
indicator_name
# Out:
# ['Adjusted net enrolment rate, upper secondary, both sexes (%)',
#  'Adult literacy rate, population 15+ years, both sexes (%)',
#  'Barro-Lee: Average years of secondary schooling, age 15+, total',
#  'Barro-Lee: Average years of tertiary schooling, age 15+, total',
#  'Barro-Lee: Percentage of population age 15+ with secondary schooling. Completed Secondary',
#  'Barro-Lee: Percentage of population age 15+ with tertiary schooling. Completed Tertiary',
#  'Graduates from tertiary education, both sexes (number)',
#  'Gross enrolment ratio, secondary, both sexes (%)',
#  'Gross enrolment ratio, tertiary, both sexes (%)',
#  'Internet users (per 100 people)',
#  'Labor force, total',
#  'Literacy rate, population 25-64 years, both sexes (%)',
#  'MICS: Net attendance rate. Secondary',
#  'MICS: Secondary completion rate',
#  'Population growth (annual %)',
#  'Population, total',
#  'School life expectancy, post-secondary non-tertiary, both sexes (years)',
# ...

# %%
#calcul du taux de remplissage 
#taux_remplissage_indicator_name=data[col="Indicator Name"].notna()/nb_ligne

# %%
#data_pivot2.columns

# %%
#mata=data[('Indicator Name')].to_string()
#print(mata)

# %%
#mycolumns=['Country Name','Country Code','Indicator Name','Indicator Code','2010']
#data.loc[:,mycolumns]
#data[mycolumns].head()

# %%
data_indicator_name=data[data['Indicator Name'].notna()]
data.head()
# Out:
#       Country Name Country Code  \
# 91625  Afghanistan          AFG
# 91626  Afghanistan          AFG
# 91627  Afghanistan          AFG
# 91628  Afghanistan          AFG
# 91629  Afghanistan          AFG
#
#                                                                 Indicator Name  \
# 91625             Adjusted net enrolment rate, lower secondary, both sexes (%)
# 91626                 Adjusted net enrolment rate, lower secondary, female (%)
# 91627  Adjusted net enrolment rate, lower secondary, gender parity index (GPI)
# 91628                   Adjusted net enrolment rate, lower secondary, male (%)
# 91629                     Adjusted net enrolment rate, primary, both sexes (%)
#
#        Indicator Code  2010  2011  2012       2013       2014  2015  2016
# 91625      UIS.NERA.2   NaN   NaN   NaN  47.436790  50.627232   NaN   NaN
# 91626    UIS.NERA.2.F   NaN   NaN   NaN  34.073261  37.641541   NaN   NaN
# ...

# %%
list_select=['Country Name','Country Code']+indicator_name
list_select
# Out:
# ['Country Name',
#  'Country Code',
#  'Adjusted net enrolment rate, upper secondary, both sexes (%)',
#  'Adult literacy rate, population 15+ years, both sexes (%)',
#  'Barro-Lee: Average years of secondary schooling, age 15+, total',
#  'Barro-Lee: Average years of tertiary schooling, age 15+, total',
#  'Barro-Lee: Percentage of population age 15+ with secondary schooling. Completed Secondary',
#  'Barro-Lee: Percentage of population age 15+ with tertiary schooling. Completed Tertiary',
#  'Graduates from tertiary education, both sexes (number)',
#  'Gross enrolment ratio, secondary, both sexes (%)',
#  'Gross enrolment ratio, tertiary, both sexes (%)',
#  'Internet users (per 100 people)',
#  'Labor force, total',
#  'Literacy rate, population 25-64 years, both sexes (%)',
#  'MICS: Net attendance rate. Secondary',
#  'MICS: Secondary completion rate',
#  'Population growth (annual %)',
#  'Population, total',
# ...

# %%
data_pivot=data[['Country Name','Country Code','Indicator Name','2010']]
data_pivot=pd.pivot_table(data_pivot,index=['Country Name','Country Code'], columns= "Indicator Name" ,values='2010').reset_index()
data_pivot.head()
# Out:
# Indicator Name    Country Name Country Code  \
# 0                  Afghanistan          AFG
# 1                      Albania          ALB
# 2                      Algeria          DZA
# 3               American Samoa          ASM
# 4                      Andorra          AND
#
# Indicator Name  Adjusted net enrolment rate, lower secondary, both sexes (%)  \
# 0                                                                        NaN
# 1                                                                        NaN
# 2                                                                        NaN
# 3                                                                        NaN
# 4                                                                        NaN
#
# Indicator Name  Adjusted net enrolment rate, lower secondary, female (%)  \
# 0                                                                    NaN
# 1                                                                    NaN
# ...

# %%
list_columns=list_select
#data_pivot2=data_pivot[list_columns]
#data_pivot2

# %%
list_columns
# Out:
# ['Country Name',
#  'Country Code',
#  'Adjusted net enrolment rate, upper secondary, both sexes (%)',
#  'Adult literacy rate, population 15+ years, both sexes (%)',
#  'Barro-Lee: Average years of secondary schooling, age 15+, total',
#  'Barro-Lee: Average years of tertiary schooling, age 15+, total',
#  'Barro-Lee: Percentage of population age 15+ with secondary schooling. Completed Secondary',
#  'Barro-Lee: Percentage of population age 15+ with tertiary schooling. Completed Tertiary',
#  'Graduates from tertiary education, both sexes (number)',
#  'Gross enrolment ratio, secondary, both sexes (%)',
#  'Gross enrolment ratio, tertiary, both sexes (%)',
#  'Internet users (per 100 people)',
#  'Labor force, total',
#  'Literacy rate, population 25-64 years, both sexes (%)',
#  'MICS: Net attendance rate. Secondary',
#  'MICS: Secondary completion rate',
#  'Population growth (annual %)',
#  'Population, total',
# ...

# %%
pivot=data_pivot[list_columns]
pivot.head()
# Out:
# Indicator Name    Country Name Country Code  \
# 0                  Afghanistan          AFG
# 1                      Albania          ALB
# 2                      Algeria          DZA
# 3               American Samoa          ASM
# 4                      Andorra          AND
#
# Indicator Name  Adjusted net enrolment rate, upper secondary, both sexes (%)  \
# 0                                                                        NaN
# 1                                                                        NaN
# 2                                                                        NaN
# 3                                                                        NaN
# 4                                                                        NaN
#
# Indicator Name  Adult literacy rate, population 15+ years, both sexes (%)  \
# 0                                                                     NaN
# 1                                                                     NaN
# ...

# %% [markdown]
# ## 5.4 Recherche de Correlation

# %%
#Calculer la matrice de corrélation et l'afficher

corrMatrix = pivot.corr()
#plt.figure(figsize=(15,15))
#sns.heatmap(corrMatrix, square=True, annot=True, linewidths=.5, cmap='coolwarm')
#plt.show()

# %%
corrMatrix.head()
# Out:
# Indicator Name                                                                             Adjusted net enrolment rate, upper secondary, both sexes (%)  \
# Indicator Name
# Adjusted net enrolment rate, upper secondary, both sexes (%)                                                                                   1.000000
# Adult literacy rate, population 15+ years, both sexes (%)                                                                                      0.758141
# Barro-Lee: Average years of secondary schooling, age 15+, total                                                                                0.806137
# Barro-Lee: Average years of tertiary schooling, age 15+, total                                                                                 0.695428
# Barro-Lee: Percentage of population age 15+ with secondary schooling. Completed Secondary                                                      0.777090
#
# ...

# %%
if DISPLAY  : 
    plt.figure(figsize=(15,15))
    mask = np.triu(corrMatrix)
    sns.heatmap(corrMatrix, square=True, annot=True, linewidths=.5, cmap='coolwarm', mask=mask)
    plt.show()

# %%
msno.heatmap(pivot)
# Out:
# /Users/FM/opt/anaconda3/lib/python3.9/site-packages/seaborn/matrix.py:305: UserWarning: Attempting to set identical left == right == 0 results in singular transformations; automatically expanding.
#   ax.set(xlim=(0, self.data.shape[1]), ylim=(0, self.data.shape[0]))
# /Users/FM/opt/anaconda3/lib/python3.9/site-packages/seaborn/matrix.py:305: UserWarning: Attempting to set identical bottom == top == 0 results in singular transformations; automatically expanding.
#   ax.set(xlim=(0, self.data.shape[1]), ylim=(0, self.data.shape[0]))
# <AxesSubplot:>

# %%
data_pivot.head()
# Out:
# Indicator Name    Country Name Country Code  \
# 0                  Afghanistan          AFG
# 1                      Albania          ALB
# 2                      Algeria          DZA
# 3               American Samoa          ASM
# 4                      Andorra          AND
#
# Indicator Name  Adjusted net enrolment rate, lower secondary, both sexes (%)  \
# 0                                                                        NaN
# 1                                                                        NaN
# 2                                                                        NaN
# 3                                                                        NaN
# 4                                                                        NaN
#
# Indicator Name  Adjusted net enrolment rate, lower secondary, female (%)  \
# 0                                                                    NaN
# 1                                                                    NaN
# ...

# %%
# boucle sur les colonnes 
print(pivot.shape)
nbre_ligne = pivot.shape[0]
#tableau_taux=[]
for col in pivot.columns :
    print(col)
    #print(data[col].isna().sum())
    #print(data[col].notna().sum())
    #calcul du taux de remplissage (sans les NaN)
    taux_remplissage = pivot[col].notna().sum()/nbre_ligne*100
    print(taux_remplissage,'%')
    #Mettre dans un tableau 
    #tableau_taux = [tableau_taux + [col, taux_remp]]
#tableau_taux
# Out:
# (216, 25)
# Country Name
# 100.0 %
# Country Code
# 100.0 %
# Adjusted net enrolment rate, upper secondary, both sexes (%)
# 26.38888888888889 %
# Adult literacy rate, population 15+ years, both sexes (%)
# 21.75925925925926 %
# Barro-Lee: Average years of secondary schooling, age 15+, total
# 66.66666666666666 %
# Barro-Lee: Average years of tertiary schooling, age 15+, total
# 66.66666666666666 %
# Barro-Lee: Percentage of population age 15+ with secondary schooling. Completed Secondary
# 66.66666666666666 %
# Barro-Lee: Percentage of population age 15+ with tertiary schooling. Completed Tertiary
# 66.66666666666666 %
# Graduates from tertiary education, both sexes (number)
# 43.51851851851852 %
# Gross enrolment ratio, secondary, both sexes (%)
# 67.5925925925926 %
# Gross enrolment ratio, tertiary, both sexes (%)
# 61.57407407407407 %
# Internet users (per 100 people)
# 93.51851851851852 %
# Labor force, total
# 86.11111111111111 %
# ...

# %%
#Barro-Lee: Percentage of population age 15+ with tertiary schooling. Completed Tertiary,/GDP per capita (current US$)/GDP per capita (current US$)/
#Internet users (per 100 people)/Population growth (annual %)/Population, total/

# %%
#liste choisie
new_list=["Country Name",
"Country Code",
"DHS: Secondary completion rate",
"GDP per capita (current US$)",
"Enrolment in tertiary education, all programmes, both sexes (number)",
"Enrolment in upper tertiary education, all programmes, both sexes (number)",
'DHS: Secondary completion rate'
"GDP per capita (current US$)",
"Internet users (per 100 people)",
"Population growth (annual %)",
"Population, total"]
new_list
# Out:
# ['Country Name',
#  'Country Code',
#  'DHS: Secondary completion rate',
#  'GDP per capita (current US$)',
#  'Enrolment in tertiary education, all programmes, both sexes (number)',
#  'Enrolment in upper tertiary education, all programmes, both sexes (number)',
#  'DHS: Secondary completion rateGDP per capita (current US$)',
#  'Internet users (per 100 people)',
#  'Population growth (annual %)',
#  'Population, total']

# %%
# sns.pairplot(pivot)

# %%
# boucle sur les colonnes
len(new_list)
#for col in new_list.columns:
 #   print(col)
# Out:
# 10

# %%
#liste choisie
new_list=["Country Name",
"Country Code",
"DHS: Secondary completion rate","GDP per capita (current US$)",
"Enrolment in tertiary education, all programmes, both sexes (number)",
"GDP per capita (current US$)",
"Internet users (per 100 people)",
"Population growth (annual %)",
"Population, total",
'Unemployment, total (% of total labor force)']
new_list
# Out:
# ['Country Name',
#  'Country Code',
#  'DHS: Secondary completion rate',
#  'GDP per capita (current US$)',
#  'Enrolment in tertiary education, all programmes, both sexes (number)',
#  'GDP per capita (current US$)',
#  'Internet users (per 100 people)',
#  'Population growth (annual %)',
#  'Population, total',
#  'Unemployment, total (% of total labor force)']

# %%
new_pivot=data_pivot[new_list]
new_pivot.head()
# Out:
# Indicator Name    Country Name Country Code  DHS: Secondary completion rate  \
# 0                  Afghanistan          AFG                             NaN
# 1                      Albania          ALB                             NaN
# 2                      Algeria          DZA                             NaN
# 3               American Samoa          ASM                             NaN
# 4                      Andorra          AND                             NaN
#
# Indicator Name  GDP per capita (current US$)  \
# 0                                 553.300289
# 1                                4094.358832
# 2                                4463.394675
# 3                               10352.822762
# 4                               39736.354063
#
# Indicator Name  Enrolment in tertiary education, all programmes, both sexes (number)  \
# 0                                                                                NaN
# ...

# %%
#chercher les NaN 
new_pivot.isna().sum()
# Out:
# Indicator Name
# Country Name                                                              0
# Country Code                                                              0
# DHS: Secondary completion rate                                          213
# GDP per capita (current US$)                                             13
# Enrolment in tertiary education, all programmes, both sexes (number)     76
# GDP per capita (current US$)                                             13
# Internet users (per 100 people)                                          14
# Population growth (annual %)                                              1
# Population, total                                                         1
# Unemployment, total (% of total labor force)                             30
# dtype: int64

# %%
#trouver les colonnes NaN
nan=new_pivot[pivot['Barro-Lee: Percentage of population age 15+ with tertiary schooling. Completed Tertiary'].isna()]
nan
# Out:
# Indicator Name           Country Name Country Code  \
# 3                      American Samoa          ASM
# 4                             Andorra          AND
# 5                              Angola          AGO
# 6                 Antigua and Barbuda          ATG
# 9                               Aruba          ABW
# ..                                ...          ...
# 200                            Tuvalu          TUV
# 207                        Uzbekistan          UZB
# 208                           Vanuatu          VUT
# 211             Virgin Islands (U.S.)          VIR
# 212                West Bank and Gaza          PSE
#
# Indicator Name  DHS: Secondary completion rate  GDP per capita (current US$)  \
# 3                                          NaN                  10352.822762
# 4                                          NaN                  39736.354063
# 5                                          NaN                   3529.053482
# ...

# %%
new_pivot=data_pivot[new_list]
new_pivot.head()
# Out:
# Indicator Name    Country Name Country Code  DHS: Secondary completion rate  \
# 0                  Afghanistan          AFG                             NaN
# 1                      Albania          ALB                             NaN
# 2                      Algeria          DZA                             NaN
# 3               American Samoa          ASM                             NaN
# 4                      Andorra          AND                             NaN
#
# Indicator Name  GDP per capita (current US$)  \
# 0                                 553.300289
# 1                                4094.358832
# 2                                4463.394675
# 3                               10352.822762
# 4                               39736.354063
#
# Indicator Name  Enrolment in tertiary education, all programmes, both sexes (number)  \
# 0                                                                                NaN
# ...

# %%
# boucle sur les colonnes 
print(new_pivot.shape)
nbre_ligne = pivot.shape[0]
#tableau_taux=[]
for col in pivot.columns :
    print(col)
    #print(data[col].isna().sum())
    #print(data[col].notna().sum())
    #calcul du taux de remplissage (sans les NaN)
    taux_remplissage = pivot[col].notna().sum()/nbre_ligne*100
    print(taux_remplissage,'%')
    #Mettre dans un tableau 
    #tableau_taux = [tableau_taux + [col, taux_remp]]
#tableau_taux
# Out:
# (216, 10)
# Country Name
# 100.0 %
# Country Code
# 100.0 %
# Adjusted net enrolment rate, upper secondary, both sexes (%)
# 26.38888888888889 %
# Adult literacy rate, population 15+ years, both sexes (%)
# 21.75925925925926 %
# Barro-Lee: Average years of secondary schooling, age 15+, total
# 66.66666666666666 %
# Barro-Lee: Average years of tertiary schooling, age 15+, total
# 66.66666666666666 %
# Barro-Lee: Percentage of population age 15+ with secondary schooling. Completed Secondary
# 66.66666666666666 %
# Barro-Lee: Percentage of population age 15+ with tertiary schooling. Completed Tertiary
# 66.66666666666666 %
# Graduates from tertiary education, both sexes (number)
# 43.51851851851852 %
# Gross enrolment ratio, secondary, both sexes (%)
# 67.5925925925926 %
# Gross enrolment ratio, tertiary, both sexes (%)
# 61.57407407407407 %
# Internet users (per 100 people)
# 93.51851851851852 %
# Labor force, total
# 86.11111111111111 %
# ...

# %%
# boucle sur les colonnes 
print(new_pivot.shape)
nbre_ligne = new_pivot.shape[0]
#tableau_taux=[]
for col in new_pivot.columns :
    print(col)
    #print(data[col].isna().sum())
    #print(data[col].notna().sum())
    #calcul du taux de remplissage (sans les NaN)
    taux_remplissage = new_pivot[col].notna().sum()/nbre_ligne*100
    print(taux_remplissage,'%')
    #Mettre dans un tableau 
    #tableau_taux = [tableau_taux + [col, taux_remp]]
#tableau_taux
# Out:
# (216, 10)
# Country Name
# 100.0 %
# Country Code
# 100.0 %
# DHS: Secondary completion rate
# 1.3888888888888888 %
# GDP per capita (current US$)
# Indicator Name
# GDP per capita (current US$)    93.981481
# GDP per capita (current US$)    93.981481
# dtype: float64 %
# Enrolment in tertiary education, all programmes, both sexes (number)
# 64.81481481481481 %
# GDP per capita (current US$)
# Indicator Name
# GDP per capita (current US$)    93.981481
# GDP per capita (current US$)    93.981481
# dtype: float64 %
# Internet users (per 100 people)
# 93.51851851851852 %
# Population growth (annual %)
# 99.53703703703704 %
# Population, total
# 99.53703703703704 %
# Unemployment, total (% of total labor force)
# 86.11111111111111 %

# %%
# Créer une nouvelle fonction qui détermine si la valeur en paramètre est manquante:
def num_missing(x):
    return sum(x.isnull())

# %%
# On applique cette fonction pour chaque colonne:
print("Valeurs manquantes par colonne:")
print(new_pivot.apply(num_missing, axis=0)) #axis=0 définit que la fonction sera bien appliquée sur chaque colonne
# Out:
# Valeurs manquantes par colonne:
# Indicator Name
# Country Name                                                              0
# Country Code                                                              0
# DHS: Secondary completion rate                                          213
# GDP per capita (current US$)                                             13
# Enrolment in tertiary education, all programmes, both sexes (number)     76
# GDP per capita (current US$)                                             13
# Internet users (per 100 people)                                          14
# Population growth (annual %)                                              1
# Population, total                                                         1
# Unemployment, total (% of total labor force)                             30
# dtype: int64

# %%
ligne=new_pivot.isna()

ligne.head()
# Out:
# Indicator Name  Country Name  Country Code  DHS: Secondary completion rate  \
# 0                      False         False                            True
# 1                      False         False                            True
# 2                      False         False                            True
# 3                      False         False                            True
# 4                      False         False                            True
#
# Indicator Name  GDP per capita (current US$)  \
# 0                                      False
# 1                                      False
# 2                                      False
# 3                                      False
# 4                                      False
#
# Indicator Name  Enrolment in tertiary education, all programmes, both sexes (number)  \
# 0                                                                               True
# ...

# %%
# boucle sur les colonnes 
##print(data.shape)
#nb_ligne = data.shape[0]
#tableau_taux=[]
for col in data.columns :
    print(col)
    taux_sup = data[col].notna().sum()/nb_ligne*100
    #print(taux_sup,'%')
    if taux_sup>= 15:
        print(taux_sup,'%')
# Out:
# Country Name
# 89.25619834710744 %
# Country Code
# 89.25619834710744 %
# Indicator Name
# 89.25619834710744 %
# Indicator Code
# 89.25619834710744 %
# 2010
# 26.3315030498461 %
# 2011
# 15.490737713235541 %
# 2012
# 15.578005028581737 %
# 2013
# 2014
# 2015
# 2016

# %%
2000,2005,2006,2007,2008,2009,2010,2011,2012,2013,
# Out:
# (2000, 2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013)

# %%
#new_pivot
#for col in data.columns:
 #   if data[col].notna().sum() / nb_ligne * 100 >= 15:
  #      col_mean = data[col].mean()
   #     print(f"The mean of column {col} is: {col_mean}")

# %%
#for i, row in data.iterrows():
   # if row.notna().sum() / len(row) * 100 >= 15:
       # row_mean = row.mean()
        #print(f"The mean of row {i} is: {row_mean}")

# %%
#for col in new_pivot.columns:
    #print(col)
    #taux_sup = new_pivot[col][new_pivot[[col, "GDP per capita (current US$)", "Internet users (per 100 people)", "Population growth (annual %)", "Population, total"]].notna().all(axis=1)].notna().sum() / nb_ligne * 100
    #print(taux_sup, '%')
   # if taux_sup >= 15:
        #print("Taux supérieur ou égal à 15%")
#Barro-Lee: Percentage of population age 15+ with tertiary schooling. Completed Tertiary 
# /GDP per capita (current US$)                                                               
#Internet users (per 100 people)                                                            
#Population growth (annual %)                                                                
#Population, total

# %%
for col in ["Barro-Lee: Percentage of population age 15+ with tertiary schooling. Completed Tertiary", "GDP per capita (current US$)", "Internet users (per 100 people)", "Population growth (annual %)", "Population, total"]:
    print(col)
    taux_sup = pivot[col].notna().sum() / len(data) * 100
    print(taux_sup, '%')
    if taux_sup >= 15:
        print(taux_sup, '%')
# Out:
# Barro-Lee: Percentage of population age 15+ with tertiary schooling. Completed Tertiary
# 0.01819008640291041 %
# GDP per capita (current US$)
# 0.0256429690263251 %
# Internet users (per 100 people)
# 0.025516648981860443 %
# Population growth (annual %)
# 0.02715880955990096 %
# Population, total
# 0.02715880955990096 %

# %%
#start_col = 'Barro-Lee: Percentage of population age 15+ with tertiary schooling. Completed Tertiary'
#end_col = 'Population, total'
#selected_cols = new_pivot.loc[:, start_col:end_col]
#row_means = selected_cols.mean(axis=1)
#print(row_means.head())

# %%
#pd.options.display.max_columns = 20

# %%
#new_pivot['mean_col'] = row_means  # ajout de la colonne à la DataFrame

#print(new_pivot)
#start_col = 'Barro-Lee: Percentage of population age 15+ with tertiary schooling. Completed Tertiary'
#end_col = 'Population, total'
#selected_cols = new_pivot.loc[:, start_col:end_col]
#row_means = selected_cols.mean(axis=1)

#new_pivot['mean_col'] = row_means  # ajout de la colonne à la DataFrame

#pd.set_option('display.max_columns', None)

#print(new_pivot.head())

# %%
key_list=['Country Name',
'Country Code',
'Barro-Lee: Percentage of population age 15+ with tertiary schooling. Completed Tertiary',
'DHS: Secondary completion rate',                                       
'GDP per capita (current US$)',                                        
'Enrolment in tertiary education, all programmes, both sexes (number)',
'Enrolment in upper secondary education, both sexes (number)',
'GDP per capita (current US$)',
'Internet users (per 100 people)',
'Population growth (annual %)',
'Unemployment, total (% of total labor force)']
key_list
# Out:
# ['Country Name',
#  'Country Code',
#  'Barro-Lee: Percentage of population age 15+ with tertiary schooling. Completed Tertiary',
#  'DHS: Secondary completion rate',
#  'GDP per capita (current US$)',
#  'Enrolment in tertiary education, all programmes, both sexes (number)',
#  'Enrolment in upper secondary education, both sexes (number)',
#  'GDP per capita (current US$)',
#  'Internet users (per 100 people)',
#  'Population growth (annual %)',
#  'Unemployment, total (% of total labor force)']

# %%
if DISPLAY : 
    msno.matrix(data)

# %%
msno.bar(data)
# Out:
# <AxesSubplot:>

# %%
data.isna().mean()
# Out:
# Country Name      0.000000
# Country Code      0.000000
# Indicator Name    0.000000
# Indicator Code    0.000000
# 2010              0.704990
# 2011              0.826446
# 2012              0.825469
# 2013              0.837497
# 2014              0.866947
# 2015              0.836754
# 2016              0.980192
# dtype: float64

# %%
#key_list=['Country Name','Country Code','Barro-Lee: Percentage of population age 15+ with tertiary schooling. Completed Tertiary',
# 'GDP per capita (current US$)',
#'Internet users (per 100 people)',
# 'Population growth (annual %)',
# 'Unemployment, total (% of total labor force)']
#data=data.loc[data.isin(key_list),:]

#data=data.loc[data.Indicator Name in key_list,:]
data = data.loc[data['Indicator Name'].isin(key_list), :]
data['Indicator Name'].unique()
# Out:
# array(['Barro-Lee: Percentage of population age 15+ with tertiary schooling. Completed Tertiary',
#        'DHS: Secondary completion rate',
#        'Enrolment in tertiary education, all programmes, both sexes (number)',
#        'Enrolment in upper secondary education, both sexes (number)',
#        'GDP per capita (current US$)', 'Internet users (per 100 people)',
#        'Population growth (annual %)',
#        'Unemployment, total (% of total labor force)'], dtype=object)

# %%
years=data.iloc[:,5:-2]
years.head()
# Out:
#                 2011           2012           2013           2014
# 92004            NaN            NaN            NaN            NaN
# 92244            NaN            NaN            NaN            NaN
# 92829   97504.000000            NaN            NaN  262874.000000
# 92839  743405.000000  881415.000000  969267.000000  968769.000000
# 92870     603.537023     669.009051     631.744971     612.069651

# %%
values_mean=years.mean(axis=1)
values_mean.head()
# Out:
# 92004              NaN
# 92244              NaN
# 92829    180189.000000
# 92839    890714.000000
# 92870       629.090174
# dtype: float64

# %%
data["values_mean"]=values_mean
data.head()
# Out:
# /var/folders/h5/kqt2k7ws47v7ktjc7dktxj580000gn/T/ipykernel_1006/438997446.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data["values_mean"]=values_mean
#       Country Name Country Code  \
# 92004  Afghanistan          AFG
# 92244  Afghanistan          AFG
# 92829  Afghanistan          AFG
# 92839  Afghanistan          AFG
# 92870  Afghanistan          AFG
#
#                                                                                 Indicator Name  \
# 92004  Barro-Lee: Percentage of population age 15+ with tertiary schooling. Completed Tertiary
# 92244                                                           DHS: Secondary completion rate
# ...

# %%
barro = data.loc[data['Indicator Name']=='Barro-Lee: Percentage of population age 15+ with tertiary schooling. Completed Tertiary','values_mean']
barro.isna().mean()
# Out:
# 1.0

# %%
pivot=pd.pivot_table(data,index=["Country Name",'Country Code'],values='values_mean',columns='Indicator Name')
pivot.head()
pivot.reset_index(inplace=True)
pivot.head()
# Out:
# Indicator Name    Country Name Country Code  DHS: Secondary completion rate  \
# 0                  Afghanistan          AFG                             NaN
# 1                      Albania          ALB                             NaN
# 2                      Algeria          DZA                             NaN
# 3               American Samoa          ASM                             NaN
# 4                      Andorra          AND                             NaN
#
# Indicator Name  Enrolment in tertiary education, all programmes, both sexes (number)  \
# 0                                                                          180189.00
# 1                                                                          160641.00
# 2                                                                         1224222.75
# 3                                                                                NaN
# 4                                                                             509.00
#
# ...

# %%
countries = pivot["Country Name"].values
countries
# Out:
# array(['Afghanistan', 'Albania', 'Algeria', 'American Samoa', 'Andorra',
#        'Angola', 'Antigua and Barbuda', 'Argentina', 'Armenia', 'Aruba',
#        'Australia', 'Austria', 'Azerbaijan', 'Bahamas, The', 'Bahrain',
#        'Bangladesh', 'Barbados', 'Belarus', 'Belgium', 'Belize', 'Benin',
#        'Bermuda', 'Bhutan', 'Bolivia', 'Bosnia and Herzegovina',
#        'Botswana', 'Brazil', 'Brunei Darussalam', 'Bulgaria',
#        'Burkina Faso', 'Burundi', 'Cabo Verde', 'Cambodia', 'Cameroon',
#        'Canada', 'Cayman Islands', 'Central African Republic', 'Chad',
#        'Channel Islands', 'Chile', 'China', 'Colombia', 'Comoros',
#        'Congo, Dem. Rep.', 'Congo, Rep.', 'Costa Rica', "Cote d'Ivoire",
#        'Croatia', 'Cuba', 'Curacao', 'Cyprus', 'Czech Republic',
#        'Denmark', 'Djibouti', 'Dominica', 'Dominican Republic', 'Ecuador',
#        'Egypt, Arab Rep.', 'El Salvador', 'Equatorial Guinea', 'Eritrea',
# ...

# %%
counts = data.groupby(['Country Name', 'Country Code'])['Indicator Name'].count()
print(counts.head())
# Out:
# Country Name    Country Code
# Afghanistan     AFG             8
# Albania         ALB             8
# Algeria         DZA             8
# American Samoa  ASM             8
# Andorra         AND             8
# Name: Indicator Name, dtype: int64

# %%
pivot.isna().mean()
# Out:
# Indicator Name
# Country Name                                                            0.000000
# Country Code                                                            0.000000
# DHS: Secondary completion rate                                          0.967442
# Enrolment in tertiary education, all programmes, both sexes (number)    0.232558
# Enrolment in upper secondary education, both sexes (number)             0.186047
# GDP per capita (current US$)                                            0.051163
# Internet users (per 100 people)                                         0.051163
# Population growth (annual %)                                            0.000000
# Unemployment, total (% of total labor force)                            0.134884
# dtype: float64

# %%
pivot['GDP per capita (current US$)'].describe()
# Out:
# count       204.000000
# mean      17101.490156
# std       25869.874062
# min         280.317504
# 25%        1815.462874
# 50%        6375.323371
# 75%       20772.166860
# max      165103.737093
# Name: GDP per capita (current US$), dtype: float64

# %%
# Filter very poor contries

pivot=pivot.loc[pivot['GDP per capita (current US$)'] >=1400,: ]
pivot.head()
# Out:
# Indicator Name    Country Name Country Code  DHS: Secondary completion rate  \
# 1                      Albania          ALB                             NaN
# 2                      Algeria          DZA                             NaN
# 3               American Samoa          ASM                             NaN
# 4                      Andorra          AND                             NaN
# 5                       Angola          AGO                             NaN
#
# Indicator Name  Enrolment in tertiary education, all programmes, both sexes (number)  \
# 1                                                                          160641.00
# 2                                                                         1224222.75
# 3                                                                                NaN
# 4                                                                             509.00
# 5                                                                          180738.50
#
# ...

# %%
pivot["GDP per capita (current US$)"] = np.log1p(pivot['GDP per capita (current US$)'] )
pivot
# Out:
# Indicator Name           Country Name Country Code  \
# 1                             Albania          ALB
# 2                             Algeria          DZA
# 3                      American Samoa          ASM
# 4                             Andorra          AND
# 5                              Angola          AGO
# ..                                ...          ...
# 209                           Vietnam          VNM
# 210             Virgin Islands (U.S.)          VIR
# 211                West Bank and Gaza          PSE
# 212                       Yemen, Rep.          YEM
# 213                            Zambia          ZMB
#
# Indicator Name  DHS: Secondary completion rate  \
# 1                                          NaN
# 2                                          NaN
# 3                                          NaN
# 4                                          NaN
# 5                                          NaN
# ..                                         ...
# ...

# %%
countries = pivot["Country Name"].values

# %%
#pivot = pivot.sort_values('score', ascending=False).round(2)
#pivot.insert(loc=1, column='country', value='Country Name')
#print(pivot.head())

# %%
pivot.isna().mean()
# Out:
# Indicator Name
# Country Name                                                            0.000000
# Country Code                                                            0.000000
# DHS: Secondary completion rate                                          0.981595
# Enrolment in tertiary education, all programmes, both sexes (number)    0.220859
# Enrolment in upper secondary education, both sexes (number)             0.159509
# GDP per capita (current US$)                                            0.000000
# Internet users (per 100 people)                                         0.030675
# Population growth (annual %)                                            0.000000
# Unemployment, total (% of total labor force)                            0.134969
# dtype: float64

# %%
from sklearn.impute import KNNImputer
pivot
# Out:
# Indicator Name           Country Name Country Code  \
# 1                             Albania          ALB
# 2                             Algeria          DZA
# 3                      American Samoa          ASM
# 4                             Andorra          AND
# 5                              Angola          AGO
# ..                                ...          ...
# 209                           Vietnam          VNM
# 210             Virgin Islands (U.S.)          VIR
# 211                West Bank and Gaza          PSE
# 212                       Yemen, Rep.          YEM
# 213                            Zambia          ZMB
#
# Indicator Name  DHS: Secondary completion rate  \
# 1                                          NaN
# 2                                          NaN
# 3                                          NaN
# 4                                          NaN
# 5                                          NaN
# ..                                         ...
# ...

# %%
x = pivot.select_dtypes(include=np.number)
cols = x.columns

imputer=KNNImputer(n_neighbors=10)
imputer.fit(x)
x=imputer.transform(x)
x
# Out:
# array([[ 5.56833333e+01,  1.60641000e+05,  1.52169500e+05, ...,
#          5.52389898e+01, -2.06106689e-01,  1.51250000e+01],
#        [ 5.56833333e+01,  1.22422275e+06,  1.33258400e+06, ...,
#          2.12750000e+01,  1.99203973e+00,  1.03500001e+01],
#        [ 5.56833333e+01,  1.19735607e+06,  6.66394025e+05, ...,
#          5.84874665e+01, -9.00301673e-02,  9.63249999e+00],
#        ...,
#        [ 5.56833333e+01,  2.14656750e+05,  1.46893500e+05, ...,
#          4.61875000e+01,  2.98647817e+00,  2.35499997e+01],
#        [ 5.56833333e+01,  2.67498000e+05,  6.61200667e+05, ...,
#          1.87253750e+01,  2.64980347e+00,  1.74749999e+01],
#        [ 5.56833333e+01,  5.62195000e+04,  2.04705867e+05, ...,
#          1.48420500e+01,  3.00817208e+00,  9.22500014e+00]])

# %%
x
# Out:
# array([[ 5.56833333e+01,  1.60641000e+05,  1.52169500e+05, ...,
#          5.52389898e+01, -2.06106689e-01,  1.51250000e+01],
#        [ 5.56833333e+01,  1.22422275e+06,  1.33258400e+06, ...,
#          2.12750000e+01,  1.99203973e+00,  1.03500001e+01],
#        [ 5.56833333e+01,  1.19735607e+06,  6.66394025e+05, ...,
#          5.84874665e+01, -9.00301673e-02,  9.63249999e+00],
#        ...,
#        [ 5.56833333e+01,  2.14656750e+05,  1.46893500e+05, ...,
#          4.61875000e+01,  2.98647817e+00,  2.35499997e+01],
#        [ 5.56833333e+01,  2.67498000e+05,  6.61200667e+05, ...,
#          1.87253750e+01,  2.64980347e+00,  1.74749999e+01],
#        [ 5.56833333e+01,  5.62195000e+04,  2.04705867e+05, ...,
#          1.48420500e+01,  3.00817208e+00,  9.22500014e+00]])

# %%
#pivot = pivot.sort_values('score', ascending=False).round(2)
#pivot.insert(loc=1, column='country', value='Country Name')
#print(pivot.head())

# %%
x=pd.DataFrame(x, columns=cols)
x.head()
# Out:
# Indicator Name  DHS: Secondary completion rate  \
# 0                                    55.683333
# 1                                    55.683333
# 2                                    55.683333
# 3                                    55.683333
# 4                                    55.683333
#
# Indicator Name  Enrolment in tertiary education, all programmes, both sexes (number)  \
# 0                                                                         160641.000
# 1                                                                        1224222.750
# 2                                                                        1197356.075
# 3                                                                            509.000
# 4                                                                         180738.500
#
# Indicator Name  Enrolment in upper secondary education, both sexes (number)  \
# 0                                                                152169.500
# ...

# %%
x["Country Name"] = countries
x
# Out:
# Indicator Name  DHS: Secondary completion rate  \
# 0                                    55.683333
# 1                                    55.683333
# 2                                    55.683333
# 3                                    55.683333
# 4                                    55.683333
# ..                                         ...
# 158                                  55.683333
# 159                                  55.683333
# 160                                  55.683333
# 161                                  55.683333
# 162                                  55.683333
#
# Indicator Name  Enrolment in tertiary education, all programmes, both sexes (number)  \
# 0                                                                         160641.000
# 1                                                                        1224222.750
# 2                                                                        1197356.075
# ...

# %%
pivot = x.copy()

# %%
pivot.isna().mean()
# Out:
# Indicator Name
# DHS: Secondary completion rate                                          0.0
# Enrolment in tertiary education, all programmes, both sexes (number)    0.0
# Enrolment in upper secondary education, both sexes (number)             0.0
# GDP per capita (current US$)                                            0.0
# Internet users (per 100 people)                                         0.0
# Population growth (annual %)                                            0.0
# Unemployment, total (% of total labor force)                            0.0
# Country Name                                                            0.0
# dtype: float64

# %%
# pip install scikit-learn

# %%
pivot
# Out:
# Indicator Name  DHS: Secondary completion rate  \
# 0                                    55.683333
# 1                                    55.683333
# 2                                    55.683333
# 3                                    55.683333
# 4                                    55.683333
# ..                                         ...
# 158                                  55.683333
# 159                                  55.683333
# 160                                  55.683333
# 161                                  55.683333
# 162                                  55.683333
#
# Indicator Name  Enrolment in tertiary education, all programmes, both sexes (number)  \
# 0                                                                         160641.000
# 1                                                                        1224222.750
# 2                                                                        1197356.075
# ...

# %% [markdown]
# # 6 Recommendation

# %% [markdown]
# ## 6.1 Taille de marché

# %%
# UPDATE Q MARCHé 


pivot = pivot.drop(columns="DHS: Secondary completion rate")
# EQUIVALENT  à  : pivot.drop(columns="DHS: Secondary completion rate", inplace=True)

pivot["Market_size"] = pivot["Enrolment in tertiary education, all programmes, both sexes (number)"] + pivot["Enrolment in upper secondary education, both sexes (number)"]

pivot
# Out:
# Indicator Name  Enrolment in tertiary education, all programmes, both sexes (number)  \
# 0                                                                         160641.000
# 1                                                                        1224222.750
# 2                                                                        1197356.075
# 3                                                                            509.000
# 4                                                                         180738.500
# ..                                                                               ...
# 158                                                                      2358213.000
# 159                                                                      4726151.800
# 160                                                                       214656.750
# 161                                                                       267498.000
# ...

# %%
pivot = pivot.drop(columns=["Enrolment in tertiary education, all programmes, both sexes (number)", 	"Enrolment in upper secondary education, both sexes (number)"])
pivot
# Out:
# Indicator Name  GDP per capita (current US$)  Internet users (per 100 people)  \
# 0                                   8.393926                        55.238990
# 1                                   8.609731                        21.275000
# 2                                   9.333198                        58.487466
# 3                                  10.611576                        89.333606
# 4                                   8.434637                         7.175000
# ..                                       ...                              ...
# 158                                 7.503992                        37.842500
# 159                                10.530103                        42.879475
# 160                                 7.955872                        46.187500
# 161                                 7.313467                        18.725375
# 162                                 7.463425                        14.842050
#
# ...

# %% [markdown]
# ## 6.2 Choix des pays

# %%
# SUPPR TROP PETITS PAYS

print(pivot.shape)

pivot.Market_size.describe()


pivot = pivot.loc[pivot.Market_size >= 1.0e+05, :]
pivot
# Out:
# (163, 6)
# Indicator Name  GDP per capita (current US$)  Internet users (per 100 people)  \
# 0                                   8.393926                        55.238990
# 1                                   8.609731                        21.275000
# 2                                   9.333198                        58.487466
# 4                                   8.434637                         7.175000
# 6                                   9.451766                        57.850000
# ..                                       ...                              ...
# 158                                 7.503992                        37.842500
# 159                                10.530103                        42.879475
# 160                                 7.955872                        46.187500
# 161                                 7.313467                        18.725375
# 162                                 7.463425                        14.842050
#
# ...

# %%
pivot.Market_size = np.log1p(pivot.Market_size)
# Out:
# /var/folders/h5/kqt2k7ws47v7ktjc7dktxj580000gn/T/ipykernel_1006/1789473991.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   pivot.Market_size = np.log1p(pivot.Market_size)

# %%
sns.displot(pivot.Market_size)

# %%
sns.boxplot(pivot.Market_size)
# Out:
# /Users/FM/opt/anaconda3/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Market_size'>

# %%
# METTRE DANS LES IMPORTS

from sklearn.preprocessing import MinMaxScaler

# %%
print(pivot.dtypes)
# Out:
# Indicator Name
# GDP per capita (current US$)                    float64
# Internet users (per 100 people)                 float64
# Population growth (annual %)                    float64
# Unemployment, total (% of total labor force)    float64
# Country Name                                     object
# Market_size                                     float64
# dtype: object

# %%
#x = pivot.select_dtypes(include=np.number)
#x = pivot.select_dtypes(include=np.number, errors='coerce')

#cols = x.columns


#scaler=MinMaxScaler()
#scaler.fit(x)
#x=scaler.transform(x)
#x

# %%
# from sklearn.preprocessing import MinMaxScaler

# x = pivot.select_dtypes(include=np.number)
# if x.shape[0] > 0:
#     cols = x.columns
#     scaler = MinMaxScaler()
#     scaler.fit(x)
#     x = scaler.transform(x)
#     print(x)
# else:
#     print("No numeric data in pivot.")

# %%
# POSSIBLE AUSSI DE FAIRE CA : 

# cf le KNN IMPUTER
countries = pivot["Country Name"].values
x = pivot.select_dtypes(include=np.number)
cols = x.columns

scaler=MinMaxScaler()
scaler.fit(x)
x=scaler.transform(x)

# ENCORE MIEUX : 
# ==> x = MinMaxScaler().fit_transform(x)


x=pd.DataFrame(x, columns=cols)


x["Country Name"] = countries
x.head()
# Out:
# Indicator Name  GDP per capita (current US$)  Internet users (per 100 people)  \
# 0                                   0.234141                         0.562527
# 1                                   0.280033                         0.187641
# 2                                   0.433878                         0.598383
# 3                                   0.242799                         0.032009
# 4                                   0.459091                         0.591346
#
# Indicator Name  Population growth (annual %)  \
# 0                                   0.145743
# 1                                   0.421498
# 2                                   0.160304
# 3                                   0.615283
# 4                                   0.302543
#
# Indicator Name  Unemployment, total (% of total labor force)  Market_size  \
# 0                                                   0.479012     0.160510
# ...

# %%
# pivot=pd.DataFrame(x,columns=cols)
# pivot["Country Name"] = countries
# pivot

# %%
pivot = x.copy()
pivot.describe().round(1)
# Out:
# Indicator Name  GDP per capita (current US$)  Internet users (per 100 people)  \
# count                                  137.0                            137.0
# mean                                     0.4                              0.5
# std                                      0.2                              0.3
# min                                      0.0                              0.0
# 25%                                      0.2                              0.3
# 50%                                      0.4                              0.5
# 75%                                      0.6                              0.7
# max                                      1.0                              1.0
#
# Indicator Name  Population growth (annual %)  \
# count                                  137.0
# mean                                     0.3
# std                                      0.2
# min                                      0.0
# ...

# %%
cols = ["gdp", "internet", "p_growth", "unemployment", "market_size", "country" ]

pivot.columns = cols
pivot
# Out:
#           gdp  internet  p_growth  unemployment  market_size  \
# 0    0.234141  0.562527  0.145743      0.479012     0.160510
# 1    0.280033  0.187641  0.421498      0.321811     0.476684
# 2    0.433878  0.598383  0.160304      0.298189     0.429103
# 3    0.242799  0.032009  0.615283      0.185185     0.226294
# 4    0.459091  0.591346  0.302543      0.218107     0.559832
# ..        ...       ...       ...           ...          ...
# 132  0.044897  0.370509  0.305653      0.044444     0.481117
# 133  0.688400  0.426106  0.109092      0.279012     0.686980
# 134  0.140989  0.462619  0.546249      0.756379     0.182302
# 135  0.004382  0.159499  0.504013      0.556379     0.324275
# 136  0.036270  0.116636  0.548970      0.284774     0.133216
#
#                    country
# 0                  Albania
# 1                  Algeria
# 2           American Samoa
# 3                   Angola
# 4                Argentina
# ..                     ...
# 132                Vietnam
# ...

# %% [markdown]
# ## 6.3 Classement final

# %%
if "score" in pivot.columns : 
    pivot = pivot.drop(columns="score")

pivot['score']=pivot.select_dtypes(include=np.number).mean(axis=1)
pivot.head()
# Out:
#         gdp  internet  p_growth  unemployment  market_size         country  \
# 0  0.234141  0.562527  0.145743      0.479012     0.160510         Albania
# 1  0.280033  0.187641  0.421498      0.321811     0.476684         Algeria
# 2  0.433878  0.598383  0.160304      0.298189     0.429103  American Samoa
# 3  0.242799  0.032009  0.615283      0.185185     0.226294          Angola
# 4  0.459091  0.591346  0.302543      0.218107     0.559832       Argentina
#
#       score
# 0  0.316387
# 1  0.337533
# 2  0.383971
# 3  0.260314
# 4  0.426184

# %%
pivot=pivot.sort_values('score',ascending=False).round(2)

# %%
if  DISPLAY : 
    sns.pairplot(pivot, corner=True)

# %%
pivot.head(20)
# Out:
#       gdp  internet  p_growth  unemployment  market_size         country  \
# 91   0.57      0.63      1.00          0.56         0.12            Oman
# 127  0.76      0.75      0.26          0.23         0.86   United States
# 110  0.64      0.74      0.17          0.78         0.52           Spain
# 126  0.72      0.93      0.26          0.22         0.60  United Kingdom
# 56   0.85      0.87      0.27          0.19         0.54     Isle of Man
# 38   0.72      0.85      0.23          0.31         0.58          France
# 18   0.76      0.89      0.31          0.22         0.49          Canada
# 6    0.81      0.85      0.37          0.16         0.47       Australia
# 80   1.00      0.92      0.26          0.24         0.20          Monaco
# 115  0.79      0.98      0.28          0.24         0.32          Sweden
# 66   0.74      0.75      0.90          0.09         0.08          Kuwait
# 90   0.90      1.00      0.33          0.09         0.23          Norway
# ...

# %%
errors = ["Oman", "Isle of Man", "France","Monaco", "Kuwait"]
pivot = pivot.loc[~ pivot.country.isin(errors), : ]
pivot.head(20)
# Out:
#       gdp  internet  p_growth  unemployment  market_size         country  \
# 127  0.76      0.75      0.26          0.23         0.86   United States
# 110  0.64      0.74      0.17          0.78         0.52           Spain
# 126  0.72      0.93      0.26          0.22         0.60  United Kingdom
# 18   0.76      0.89      0.31          0.22         0.49          Canada
# 6    0.81      0.85      0.37          0.16         0.47       Australia
# 115  0.79      0.98      0.28          0.24         0.32          Sweden
# 90   0.90      1.00      0.33          0.09         0.23          Norway
# 85   0.76      0.97      0.22          0.19         0.40     Netherlands
# 60   0.72      0.88      0.15          0.12         0.64           Japan
# 41   0.73      0.87      0.14          0.16         0.59         Germany
# 27   0.79      0.98      0.23          0.22         0.25         Denmark
# 116  0.87      0.90      0.31          0.12         0.26     Switzerland
# ...

# %%
pivot.to_csv("classement_final.csv", index=False)

# %%
pivot.head(10).style.highlight_max(color = 'lightgreen', axis = 0)
# Out:
# <style type="text/css">
# #T_b03e4_row0_col4, #T_b03e4_row0_col5, #T_b03e4_row0_col6, #T_b03e4_row1_col3, #T_b03e4_row1_col6, #T_b03e4_row4_col2, #T_b03e4_row6_col0, #T_b03e4_row6_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_b03e4">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_b03e4_level0_col0" class="col_heading level0 col0" >gdp</th>
#       <th id="T_b03e4_level0_col1" class="col_heading level0 col1" >internet</th>
#       <th id="T_b03e4_level0_col2" class="col_heading level0 col2" >p_growth</th>
#       <th id="T_b03e4_level0_col3" class="col_heading level0 col3" >unemployment</th>
#       <th id="T_b03e4_level0_col4" class="col_heading level0 col4" >market_size</th>
#       <th id="T_b03e4_level0_col5" class="col_heading level0 col5" >country</th>
#       <th id="T_b03e4_level0_col6" class="col_heading level0 col6" >score</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
# ...
